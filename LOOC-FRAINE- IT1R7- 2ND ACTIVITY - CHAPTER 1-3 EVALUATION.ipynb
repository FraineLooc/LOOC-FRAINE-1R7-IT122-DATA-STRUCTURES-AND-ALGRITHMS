# %%
print("CHAPTER 1:")
print("")
print("Learnings:")
print("")
print("-	Correctness it should be implemented correctly.")
print("")
print("-	In a characteristics of a data structure time complexity must be small as possible, easy to render. ")
print("")
print("-	Space complexity, very important that you should consider the memory usage of the data structure operation should be as little as possible.")
print("")
print("-	When you create program system, when you create solution to your program it should run as fast as possible and it must take little memory as possible")
print("")
print("-	Worst case is where a particular data structure operation takes maximum time it can take.")
print("")
print("-	Average case depicting the average execution time of an operation of a data structure.")
print("")
print("-	Best case depicting the least possible execution time of an operation of a data structure.")
print("")
print("-	Search application is when you want to search an item ")
print("")
print("-	Sort when you want to sort an item a certain order.")
print("")
print("-	Insert when you want to insert.")
print("")
print("-	 Update when you want to update an existing item.")
print("")
print("-	 Delete when you want to delete an existing item from a data structure. (165)")
print("")
print("-	There are no well-defined standards for writing algorithms. Algorithms are never written to support a particular programming code.")
print("")
print("All programming languages share basic code constructs like loops (do, for, while), flow-control (if-else), etc.")
print("")
print("We write algorithms in a step-by-step manner, but it is not always the case. Algorithm writing is a process and is executed after the problem domain is well-defined.")
print("")
print("")
# Out:
# CHAPTER 1:
#
# Learnings:
#
# -	Correctness it should be implemented correctly.
#
# -	In a characteristics of a data structure time complexity must be small as possible, easy to render.
#
# -	Space complexity, very important that you should consider the memory usage of the data structure operation should be as little as possible.
#
# -	When you create program system, when you create solution to your program it should run as fast as possible and it must take little memory as possible
#
# -	Worst case is where a particular data structure operation takes maximum time it can take.
#
# -	Average case depicting the average execution time of an operation of a data structure.
#
# -	Best case depicting the least possible execution time of an operation of a data structure.
#
# -	Search application is when you want to search an item
#
# -	Sort when you want to sort an item a certain order.
#
# -	Insert when you want to insert.
#
# -	 Update when you want to update an existing item.
#
# ...

# %%
print("CHAPTER 2 ")
print("")
print("")
print("Learnings: ")
print("")
print("")
print("-	Those data types for which a language has built-in support are known as Built-in Data types. Integers (a whole number: a number that is not a function), Boolean (true, false), Floating (Decimal numbers), Character and strings, these are most of the language provide the following built-in data types. ")
print("")
print("")
print("-	Derived Data Type are those data types which are implementation-independent as they can be implemented in one of the other way are known as derived data types. These data types are normally built by the combination of primary or built in data types and associated operations on them. List, Array, Stack, Queue.")
print("")
print("")
print("-	Basic Operations are the data in the data structures are processed by certain operations. The particular data structure chosen largely depends on the frequency of the operation that needs to be performed on the data structure. Examples are Traversing, Searching, Insertion, Deletion, Sorting and Merging.")
print("")
print("")
print("")
# Out:
# CHAPTER 2
#
#
# Learnings:
#
#
# -	Those data types for which a language has built-in support are known as Built-in Data types. Integers (a whole number: a number that is not a function), Boolean (true, false), Floating (Decimal numbers), Character and strings, these are most of the language provide the following built-in data types.
#
#
# -	Derived Data Type are those data types which are implementation-independent as they can be implemented in one of the other way are known as derived data types. These data types are normally built by the combination of primary or built in data types and associated operations on them. List, Array, Stack, Queue.
#
#
# -	Basic Operations are the data in the data structures are processed by certain operations. The particular data structure chosen largely depends on the frequency of the operation that needs to be performed on the data structure. Examples are Traversing, Searching, Insertion, Deletion, Sorting and Merging.

# %%
print("CHAPTER 3")
print("")
print("")
print("Learnings:")
print("")
print("-	In Array Representation, Arrays can be declared in various ways in different languages.")
print("")
print("-	Basic Operations are Traverse, Insertion, Deletion, Search and Update.")
print("")
print("-	Traverse print all the array elements one by one.")
print("")
print("-	Insertion adds an element at the given index.")
print("")
print("-	Deletion deletes an element at the given index.")
print("")
print("-	Search, searches an element using the given index.")
print("")
print("-	Update, updates an element at the given index.")
print("")
print("-	Array is created in Python b importing array module to the python program (“from array import*”).")
print("")
print("-	The array uses a continuous memory space to store a set of data of the same type. The biggest feature is to support random access, but the insertion and deletion operations have become relatively inefficient, and the usual business development.")
print("")
print("-	Typecode are the codes that are used to define the type of value the array will hold.")
print("")
print("•	b – Represents signed integer of size 1 byte/td>")
print("")
print("•	B – Represents unsigned integer of size 1 byte")
print("")
print("•	c – Represents character of size 1 byte")
print("")
print("•	i – Represents signed integer of size 2 bytes")
print("")
print("•	l – Represents unsigned integer of size 2 bytes")
print("")
print("•	f – Represents floating point of size 4 bytes")
print("")
print("•	d – Represents floating point of size 8 bytes ")
print("")
print("")
# Out:
# CHAPTER 3
#
#
# Learnings:
#
# -	In Array Representation, Arrays can be declared in various ways in different languages.
#
# -	Basic Operations are Traverse, Insertion, Deletion, Search and Update.
#
# -	Traverse print all the array elements one by one.
#
# -	Insertion adds an element at the given index.
#
# -	Deletion deletes an element at the given index.
#
# -	Search, searches an element using the given index.
#
# -	Update, updates an element at the given index.
#
# -	Array is created in Python b importing array module to the python program (“from array import*”).
#
# -	The array uses a continuous memory space to store a set of data of the same type. The biggest feature is to support random access, but the insertion and deletion operations have become relatively inefficient, and the usual business development.
#
# -	Typecode are the codes that are used to define the type of value the array will hold.
#
# •	b – Represents signed integer of size 1 byte/td>
#
# ...
